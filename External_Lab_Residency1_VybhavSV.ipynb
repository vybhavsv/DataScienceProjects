# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd
classiris = pd.read_csv('D:\SRDownloads\Iris_external.csv')
#classiris.index = classiris['Sepal Length (in cm)']
#classiris.describe()
# Out:
#        Sepal Length (in cm)  ...  Petal width (in cm)
# count            150.000000  ...           150.000000
# mean               5.843333  ...             1.198667
# std                0.828066  ...             0.763161
# min                4.300000  ...             0.100000
# 25%                5.100000  ...             0.300000
# 50%                5.800000  ...             1.300000
# 75%                6.400000  ...             1.800000
# max                7.900000  ...             2.500000
#
# [8 rows x 4 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
classiris.info()
print('\n')
print('Iris Flowers Class DataFrame Type')
print('\n')
print(classiris.dtypes)
print('\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 150 entries, 5.1 to 5.9
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 12.0+ KB
#
#
# Iris Flowers Class DataFrame Type
#
#
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
classiris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
# 5                   5.4                  3.9  ...                  0.4  Iris-setosa
# 6                   4.6                  3.4  ...                  0.3  Iris-setosa
# 7                   5.0                  3.4  ...                  0.2  Iris-setosa
# 8                   4.4                  2.9  ...                  0.2  Iris-setosa
# 9                   4.9                  3.1  ...                  0.1  Iris-setosa
#
# [10 rows x 5 columns]

# %%
classiris.tail(10)
# Out:
#      Sepal Length (in cm)  ...           Class
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
print('Iris Flowers Class DataFrame Shape')
classiris.shape
# Out:
# Iris Flowers Class DataFrame Shape
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
classiris.columns
# Out:
# Index(['Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
#        'Petal width (in cm)', 'Class'],
#       dtype='object')

# %%
classiris.index = classiris['Sepal Length (in cm)']
classiris.head(5)
# Out:
#                       Sepal Length (in cm)  ...        Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 4.7                                    4.7  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
#classiris['Petal length (in cm)'].head(5)
classiris.iloc[:,2]
# Out:
# Sepal Length (in cm)
# 5.1    1.4
# 4.9    1.4
# 4.7    1.3
# 4.6    1.5
# 5.0    1.4
# 5.4    1.7
# 4.6    1.4
# 5.0    1.5
# 4.4    1.4
# 4.9    1.5
# 5.4    1.5
# 4.8    1.6
# 4.8    1.4
# 4.3    1.1
# 5.8    1.2
# 5.7    1.5
# 5.4    1.3
# 5.1    1.4
# 5.7    1.7
# 5.1    1.5
# 5.4    1.7
# 5.1    1.5
# 4.6    1.0
# 5.1    1.7
# 4.8    1.9
# 5.0    1.6
# 5.0    1.6
# 5.2    1.5
# 5.2    1.4
# 4.7    1.6
#       ...
# 6.9    5.7
# 5.6    4.9
# 7.7    6.7
# 6.3    4.9
# 6.7    5.7
# 7.2    6.0
# 6.2    4.8
# 6.1    4.9
# 6.4    5.6
# 7.2    5.8
# 7.4    6.1
# 7.9    6.4
# 6.4    5.6
# 6.3    5.1
# 6.1    5.6
# 7.7    6.1
# 6.3    5.6
# 6.4    5.5
# 6.0    4.8
# 6.9    5.4
# 6.7    5.6
# 6.9    5.1
# 5.8    5.1
# 6.8    5.9
# 6.7    5.7
# 6.7    5.2
# 6.3    5.0
# 6.5    5.2
# 6.2    5.4
# 5.9    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
classiris.iloc[:10,:2]
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1

# %%
classiris[['Sepal Width in (cm)','Sepal Length (in cm)']].head(10)
# Out:
#                       Sepal Width in (cm)  Sepal Length (in cm)
# Sepal Length (in cm)
# 5.1                                   3.5                   5.1
# 4.9                                   3.0                   4.9
# 4.7                                   3.2                   4.7
# 4.6                                   3.1                   4.6
# 5.0                                   3.6                   5.0
# 5.4                                   3.9                   5.4
# 4.6                                   3.4                   4.6
# 5.0                                   3.4                   5.0
# 4.4                                   2.9                   4.4
# 4.9                                   3.1                   4.9

# %%
classiris.iloc[:10,:-3]
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
classiris[classiris['Class']=='Iris-setosa']
# Out:
#                       Sepal Length (in cm)  ...        Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 4.7                                    4.7  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 4.3                                    4.3  ...  Iris-setosa
# 5.8                                    5.8  ...  Iris-setosa
# 5.7                                    5.7  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 5.7                                    5.7  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.2                                    5.2  ...  Iris-setosa
# 5.2                                    5.2  ...  Iris-setosa
# 4.7                                    4.7  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 5.4                                    5.4  ...  Iris-setosa
# 5.2                                    5.2  ...  Iris-setosa
# 5.5                                    5.5  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.5                                    5.5  ...  Iris-setosa
# 4.9                                    4.9  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 4.5                                    4.5  ...  Iris-setosa
# 4.4                                    4.4  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.8                                    4.8  ...  Iris-setosa
# 5.1                                    5.1  ...  Iris-setosa
# 4.6                                    4.6  ...  Iris-setosa
# 5.3                                    5.3  ...  Iris-setosa
# 5.0                                    5.0  ...  Iris-setosa
#
# [50 rows x 5 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
classiris['SepalExtra']=classiris['Sepal Length (in cm)']*classiris['Sepal Width in (cm)']
classiris
# Out:
#                       Sepal Length (in cm)  ...  SepalExtra
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...       17.85
# 4.9                                    4.9  ...       14.70
# 4.7                                    4.7  ...       15.04
# 4.6                                    4.6  ...       14.26
# 5.0                                    5.0  ...       18.00
# 5.4                                    5.4  ...       21.06
# 4.6                                    4.6  ...       15.64
# 5.0                                    5.0  ...       17.00
# 4.4                                    4.4  ...       12.76
# 4.9                                    4.9  ...       15.19
# 5.4                                    5.4  ...       19.98
# 4.8                                    4.8  ...       16.32
# 4.8                                    4.8  ...       14.40
# 4.3                                    4.3  ...       12.90
# 5.8                                    5.8  ...       23.20
# 5.7                                    5.7  ...       25.08
# 5.4                                    5.4  ...       21.06
# 5.1                                    5.1  ...       17.85
# 5.7                                    5.7  ...       21.66
# 5.1                                    5.1  ...       19.38
# 5.4                                    5.4  ...       18.36
# 5.1                                    5.1  ...       18.87
# 4.6                                    4.6  ...       16.56
# 5.1                                    5.1  ...       16.83
# 4.8                                    4.8  ...       16.32
# 5.0                                    5.0  ...       15.00
# 5.0                                    5.0  ...       17.00
# 5.2                                    5.2  ...       18.20
# 5.2                                    5.2  ...       17.68
# 4.7                                    4.7  ...       15.04
# ...                                    ...  ...         ...
# 6.9                                    6.9  ...       22.08
# 5.6                                    5.6  ...       15.68
# 7.7                                    7.7  ...       21.56
# 6.3                                    6.3  ...       17.01
# 6.7                                    6.7  ...       22.11
# 7.2                                    7.2  ...       23.04
# 6.2                                    6.2  ...       17.36
# 6.1                                    6.1  ...       18.30
# 6.4                                    6.4  ...       17.92
# 7.2                                    7.2  ...       21.60
# 7.4                                    7.4  ...       20.72
# 7.9                                    7.9  ...       30.02
# 6.4                                    6.4  ...       17.92
# 6.3                                    6.3  ...       17.64
# 6.1                                    6.1  ...       15.86
# 7.7                                    7.7  ...       23.10
# 6.3                                    6.3  ...       21.42
# 6.4                                    6.4  ...       19.84
# 6.0                                    6.0  ...       18.00
# 6.9                                    6.9  ...       21.39
# 6.7                                    6.7  ...       20.77
# 6.9                                    6.9  ...       21.39
# 5.8                                    5.8  ...       15.66
# 6.8                                    6.8  ...       21.76
# 6.7                                    6.7  ...       22.11
# 6.7                                    6.7  ...       20.10
# 6.3                                    6.3  ...       15.75
# 6.5                                    6.5  ...       19.50
# 6.2                                    6.2  ...       21.08
# 5.9                                    5.9  ...       17.70
#
# [150 rows x 6 columns]

# %%
classiris['SepalExtra']=classiris.iloc[:,0]*classiris.iloc[:,1]
classiris
# Out:
#                       Sepal Length (in cm)  ...  SepalExtra
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...       17.85
# 4.9                                    4.9  ...       14.70
# 4.7                                    4.7  ...       15.04
# 4.6                                    4.6  ...       14.26
# 5.0                                    5.0  ...       18.00
# 5.4                                    5.4  ...       21.06
# 4.6                                    4.6  ...       15.64
# 5.0                                    5.0  ...       17.00
# 4.4                                    4.4  ...       12.76
# 4.9                                    4.9  ...       15.19
# 5.4                                    5.4  ...       19.98
# 4.8                                    4.8  ...       16.32
# 4.8                                    4.8  ...       14.40
# 4.3                                    4.3  ...       12.90
# 5.8                                    5.8  ...       23.20
# 5.7                                    5.7  ...       25.08
# 5.4                                    5.4  ...       21.06
# 5.1                                    5.1  ...       17.85
# 5.7                                    5.7  ...       21.66
# 5.1                                    5.1  ...       19.38
# 5.4                                    5.4  ...       18.36
# 5.1                                    5.1  ...       18.87
# 4.6                                    4.6  ...       16.56
# 5.1                                    5.1  ...       16.83
# 4.8                                    4.8  ...       16.32
# 5.0                                    5.0  ...       15.00
# 5.0                                    5.0  ...       17.00
# 5.2                                    5.2  ...       18.20
# 5.2                                    5.2  ...       17.68
# 4.7                                    4.7  ...       15.04
# ...                                    ...  ...         ...
# 6.9                                    6.9  ...       22.08
# 5.6                                    5.6  ...       15.68
# 7.7                                    7.7  ...       21.56
# 6.3                                    6.3  ...       17.01
# 6.7                                    6.7  ...       22.11
# 7.2                                    7.2  ...       23.04
# 6.2                                    6.2  ...       17.36
# 6.1                                    6.1  ...       18.30
# 6.4                                    6.4  ...       17.92
# 7.2                                    7.2  ...       21.60
# 7.4                                    7.4  ...       20.72
# 7.9                                    7.9  ...       30.02
# 6.4                                    6.4  ...       17.92
# 6.3                                    6.3  ...       17.64
# 6.1                                    6.1  ...       15.86
# 7.7                                    7.7  ...       23.10
# 6.3                                    6.3  ...       21.42
# 6.4                                    6.4  ...       19.84
# 6.0                                    6.0  ...       18.00
# 6.9                                    6.9  ...       21.39
# 6.7                                    6.7  ...       20.77
# 6.9                                    6.9  ...       21.39
# 5.8                                    5.8  ...       15.66
# 6.8                                    6.8  ...       21.76
# 6.7                                    6.7  ...       22.11
# 6.7                                    6.7  ...       20.10
# 6.3                                    6.3  ...       15.75
# 6.5                                    6.5  ...       19.50
# 6.2                                    6.2  ...       21.08
# 5.9                                    5.9  ...       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
classiris.describe()
# Out:
#        Sepal Length (in cm)  ...  SepalExtra
# count            150.000000  ...  150.000000
# mean               5.843333  ...   17.806533
# std                0.828066  ...    3.368693
# min                4.300000  ...   10.000000
# 25%                5.100000  ...   15.645000
# 50%                5.800000  ...   17.660000
# 75%                6.400000  ...   20.325000
# max                7.900000  ...   30.020000
#
# [8 rows x 5 columns]

# %%
classiris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
classiris.mean(axis=0)
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
classiris.var()
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %%
classiris.var(axis=0)
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_func(*arg): 
    print("Displaying Fifth Row's , First Two Column Values")
    print(arg[0], arg[1]) 
    return 

#print_func(1,2)
#print('\n')
print_func(classiris.iloc[5,0],classiris.iloc[5,1])
# Out:
# Displaying Fifth Row's , First Two Column Values
# 5.4 3.9

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
print(classiris['Sepal Length (in cm)'].max() - classiris['Sepal Length (in cm)'].min())
# Out:
# 3.6000000000000005

# %%
print(classiris['Sepal Width in (cm)'].max() - classiris['Sepal Width in (cm)'].min())
# Out:
# 2.4000000000000004

# %%
print(classiris['Petal length (in cm)'].max() - classiris['Petal length (in cm)'].min())
# Out:
# 5.9

# %%
print(classiris['Petal width (in cm)'].max() - classiris['Petal width (in cm)'].min())
# Out:
# 2.4

# %%
classirisextra = classiris.describe()
classirisextra.drop('SepalExtra',axis=1,inplace=True)
classirisextra
new_var = {'Sepal Length (in cm)':(classiris['Sepal Length (in cm)'].var()), 'Sepal Width in (cm)':(classiris['Sepal Width in (cm)'].var()), 'Petal length (in cm)':(classiris['Petal length (in cm)'].var()), 'Petal width (in cm)':(classiris['Petal width (in cm)'].var())}
classirisextra = classirisextra.append(new_var, ignore_index=True)
new_range = {'Sepal Length (in cm)':(classiris['Sepal Length (in cm)'].max() - classiris['Sepal Length (in cm)'].min()), 'Sepal Width in (cm)':(classiris['Sepal Width in (cm)'].max() - classiris['Sepal Width in (cm)'].min()), 'Petal length (in cm)':(classiris['Petal length (in cm)'].max() - classiris['Petal length (in cm)'].min()), 'Petal width (in cm)':(classiris['Petal width (in cm)'].max() - classiris['Petal width (in cm)'].min())}
classirisextra = classirisextra.append(new_range, ignore_index=True)
classirisextra['Index'] = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', 'var', 'range']
classirisextra.set_index('Index',inplace=True)
classirisextra
# Out:
#        Sepal Length (in cm)  ...  Petal width (in cm)
# Index                        ...
# count            150.000000  ...           150.000000
# mean               5.843333  ...             1.198667
# std                0.828066  ...             0.763161
# min                4.300000  ...             0.100000
# 25%                5.100000  ...             0.300000
# 50%                5.800000  ...             1.300000
# 75%                6.400000  ...             1.800000
# max                7.900000  ...             2.500000
# var                0.685694  ...             0.582414
# range              3.600000  ...             2.400000
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
classiris.sort_values(['Petal width (in cm)'], ascending=[True])
# Out:
#                       Sepal Length (in cm)  ...  SepalExtra
# Sepal Length (in cm)                        ...
# 5.2                                    5.2  ...       21.32
# 4.3                                    4.3  ...       12.90
# 4.9                                    4.9  ...       15.19
# 4.9                                    4.9  ...       15.19
# 4.8                                    4.8  ...       14.40
# 4.9                                    4.9  ...       15.19
# 5.1                                    5.1  ...       17.85
# 5.2                                    5.2  ...       18.20
# 5.2                                    5.2  ...       17.68
# 4.7                                    4.7  ...       15.04
# 4.8                                    4.8  ...       14.88
# 5.5                                    5.5  ...       23.10
# 5.5                                    5.5  ...       19.25
# 4.4                                    4.4  ...       13.20
# 5.1                                    5.1  ...       17.34
# 4.4                                    4.4  ...       14.08
# 5.1                                    5.1  ...       19.38
# 4.6                                    4.6  ...       14.72
# 5.3                                    5.3  ...       19.61
# 5.0                                    5.0  ...       16.50
# 5.0                                    5.0  ...       15.00
# 4.8                                    4.8  ...       16.32
# 5.0                                    5.0  ...       16.00
# 4.6                                    4.6  ...       14.26
# 4.7                                    4.7  ...       15.04
# 5.0                                    5.0  ...       17.00
# 4.4                                    4.4  ...       12.76
# 5.4                                    5.4  ...       19.98
# 5.0                                    5.0  ...       18.00
# 4.8                                    4.8  ...       16.32
# ...                                    ...  ...         ...
# 6.4                                    6.4  ...       17.28
# 5.6                                    5.6  ...       15.68
# 7.7                                    7.7  ...       21.56
# 6.5                                    6.5  ...       19.50
# 5.7                                    5.7  ...       14.25
# 7.9                                    7.9  ...       30.02
# 6.5                                    6.5  ...       20.80
# 6.9                                    6.9  ...       21.39
# 7.1                                    7.1  ...       21.30
# 6.8                                    6.8  ...       20.40
# 7.6                                    7.6  ...       22.80
# 6.7                                    6.7  ...       22.11
# 6.4                                    6.4  ...       17.92
# 7.7                                    7.7  ...       29.26
# 6.4                                    6.4  ...       17.92
# 6.5                                    6.5  ...       19.50
# 6.9                                    6.9  ...       22.08
# 6.4                                    6.4  ...       20.48
# 6.2                                    6.2  ...       21.08
# 6.9                                    6.9  ...       21.39
# 6.8                                    6.8  ...       21.76
# 6.7                                    6.7  ...       20.10
# 7.7                                    7.7  ...       20.02
# 7.7                                    7.7  ...       23.10
# 6.3                                    6.3  ...       21.42
# 6.7                                    6.7  ...       20.77
# 5.8                                    5.8  ...       16.24
# 6.3                                    6.3  ...       20.79
# 6.7                                    6.7  ...       22.11
# 7.2                                    7.2  ...       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
classiris.drop('SepalExtra',axis=1,inplace=True)
# Out:
#                       Sepal Length (in cm)  ...           Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...     Iris-setosa
# 4.9                                    4.9  ...     Iris-setosa
# 4.7                                    4.7  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 4.4                                    4.4  ...     Iris-setosa
# 4.9                                    4.9  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 4.3                                    4.3  ...     Iris-setosa
# 5.8                                    5.8  ...     Iris-setosa
# 5.7                                    5.7  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 5.7                                    5.7  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.2                                    5.2  ...     Iris-setosa
# 5.2                                    5.2  ...     Iris-setosa
# 4.7                                    4.7  ...     Iris-setosa
# ...                                    ...  ...             ...
# 6.9                                    6.9  ...  Iris-virginica
# 5.6                                    5.6  ...  Iris-virginica
# 7.7                                    7.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 7.2                                    7.2  ...  Iris-virginica
# 6.2                                    6.2  ...  Iris-virginica
# 6.1                                    6.1  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 7.2                                    7.2  ...  Iris-virginica
# 7.4                                    7.4  ...  Iris-virginica
# 7.9                                    7.9  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.1                                    6.1  ...  Iris-virginica
# 7.7                                    7.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 6.0                                    6.0  ...  Iris-virginica
# 6.9                                    6.9  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.9                                    6.9  ...  Iris-virginica
# 5.8                                    5.8  ...  Iris-virginica
# 6.8                                    6.8  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.5                                    6.5  ...  Iris-virginica
# 6.2                                    6.2  ...  Iris-virginica
# 5.9                                    5.9  ...  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=classiris[['Sepal Length (in cm)','Sepal Width in (cm)','Petal length (in cm)']].head(10)

# %%
IrisSubset
# Out:
#                       Sepal Length (in cm)  ...  Petal length (in cm)
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...                   1.4
# 4.9                                    4.9  ...                   1.4
# 4.7                                    4.7  ...                   1.3
# 4.6                                    4.6  ...                   1.5
# 5.0                                    5.0  ...                   1.4
# 5.4                                    5.4  ...                   1.7
# 4.6                                    4.6  ...                   1.4
# 5.0                                    5.0  ...                   1.5
# 4.4                                    4.4  ...                   1.4
# 4.9                                    4.9  ...                   1.5
#
# [10 rows x 3 columns]

# %%
IrisSubset=classiris.iloc[:10,:3]
IrisSubset
# Out:
#                       Sepal Length (in cm)  ...  Petal length (in cm)
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...                   1.4
# 4.9                                    4.9  ...                   1.4
# 4.7                                    4.7  ...                   1.3
# 4.6                                    4.6  ...                   1.5
# 5.0                                    5.0  ...                   1.4
# 5.4                                    5.4  ...                   1.7
# 4.6                                    4.6  ...                   1.4
# 5.0                                    5.0  ...                   1.5
# 4.4                                    4.4  ...                   1.4
# 4.9                                    4.9  ...                   1.5
#
# [10 rows x 3 columns]

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR_Ext_df = pd.read_csv('D:\SRDownloads\HR_external.txt', sep='\t')
HR_Ext_df
# Out:
#      Individual Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0          Ind1       Yes  ...                        0                     5
# 1          Ind2        No  ...                        1                     7
# 2          Ind3       Yes  ...                        0                     0
# 3          Ind4        No  ...                        3                     0
# 4          Ind5        No  ...                        2                     2
# 5          Ind6        No  ...                        3                     6
# 6          Ind7        No  ...                        0                     0
# 7          Ind8        No  ...                        0                     0
# 8          Ind9        No  ...                        1                     8
# 9         Ind10        No  ...                        7                     7
# 10        Ind11        No  ...                        0                     3
# 11        Ind12        No  ...                        0                     8
# 12        Ind13        No  ...                        4                     3
# 13        Ind14        No  ...                        1                     2
# 14        Ind15       Yes  ...                        0                     3
# 15        Ind16        No  ...                        8                     8
# 16        Ind17        No  ...                        0                     5
# 17        Ind18        No  ...                        0                     0
# 18        Ind19        No  ...                        3                     7
# 19        Ind20        No  ...                        1                     2
# 20        Ind21        No  ...                        1                     3
# 21        Ind22       Yes  ...                        0                     3
# 22        Ind23        No  ...                        2                    11
# 23        Ind24        No  ...                        0                     0
# 24        Ind25       Yes  ...                        1                     3
# 25        Ind26        No  ...                        4                     8
# 26        Ind27       Yes  ...                        6                     7
# 27        Ind28        No  ...                        4                     2
# 28        Ind29        No  ...                        5                    17
# 29        Ind30        No  ...                        2                     1
# ...         ...       ...  ...                      ...                   ...
# 1440    Ind1441        No  ...                        0                     2
# 1441    Ind1442        No  ...                        1                     9
# 1442    Ind1443       Yes  ...                        2                     2
# 1443    Ind1444        No  ...                        4                    14
# 1444    Ind1445       Yes  ...                        9                     8
# 1445    Ind1446        No  ...                        0                    10
# 1446    Ind1447        No  ...                        1                     7
# 1447    Ind1448        No  ...                       11                    11
# 1448    Ind1449        No  ...                        0                     4
# 1449    Ind1450        No  ...                        1                     2
# 1450    Ind1451        No  ...                        1                     7
# 1451    Ind1452        No  ...                        1                     9
# 1452    Ind1453       Yes  ...                        0                     1
# 1453    Ind1454        No  ...                        0                     0
# 1454    Ind1455        No  ...                        0                     1
# 1455    Ind1456        No  ...                        2                     2
# 1456    Ind1457        No  ...                        0                     2
# 1457    Ind1458        No  ...                        0                     2
# 1458    Ind1459        No  ...                        1                     1
# 1459    Ind1460        No  ...                        0                     3
# 1460    Ind1461        No  ...                        0                     4
# 1461    Ind1462       Yes  ...                        2                     0
# 1462    Ind1463        No  ...                        9                     6
# 1463    Ind1464        No  ...                        1                     7
# 1464    Ind1465        No  ...                        0                     0
# 1465    Ind1466        No  ...                        0                     3
# 1466    Ind1467        No  ...                        1                     7
# 1467    Ind1468        No  ...                        0                     3
# 1468    Ind1469        No  ...                        0                     8
# 1469    Ind1470        No  ...                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
HR_Ext_df.shape
# Out:
# (1470, 35)

# %%
print(len(HR_Ext_df))
# Out:
# 1470

# %%
print(len(HR_Ext_df.columns))
# Out:
# 35

# %%
HR_Ext_df.size
# Out:
# 51450

# %%
HR_Ext_df.count
# Out:
# <bound method DataFrame.count of      Individual Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0          Ind1       Yes  ...                        0                     5
# 1          Ind2        No  ...                        1                     7
# 2          Ind3       Yes  ...                        0                     0
# 3          Ind4        No  ...                        3                     0
# 4          Ind5        No  ...                        2                     2
# 5          Ind6        No  ...                        3                     6
# 6          Ind7        No  ...                        0                     0
# 7          Ind8        No  ...                        0                     0
# 8          Ind9        No  ...                        1                     8
# 9         Ind10        No  ...                        7                     7
# 10        Ind11        No  ...                        0                     3
# 11        Ind12        No  ...                        0                     8
# 12        Ind13        No  ...                        4                     3
# 13        Ind14        No  ...                        1                     2
# 14        Ind15       Yes  ...                        0                     3
# 15        Ind16        No  ...                        8                     8
# 16        Ind17        No  ...                        0                     5
# 17        Ind18        No  ...                        0                     0
# 18        Ind19        No  ...                        3                     7
# 19        Ind20        No  ...                        1                     2
# 20        Ind21        No  ...                        1                     3
# 21        Ind22       Yes  ...                        0                     3
# 22        Ind23        No  ...                        2                    11
# 23        Ind24        No  ...                        0                     0
# 24        Ind25       Yes  ...                        1                     3
# 25        Ind26        No  ...                        4                     8
# 26        Ind27       Yes  ...                        6                     7
# 27        Ind28        No  ...                        4                     2
# 28        Ind29        No  ...                        5                    17
# 29        Ind30        No  ...                        2                     1
# ...         ...       ...  ...                      ...                   ...
# 1440    Ind1441        No  ...                        0                     2
# 1441    Ind1442        No  ...                        1                     9
# 1442    Ind1443       Yes  ...                        2                     2
# 1443    Ind1444        No  ...                        4                    14
# 1444    Ind1445       Yes  ...                        9                     8
# 1445    Ind1446        No  ...                        0                    10
# 1446    Ind1447        No  ...                        1                     7
# 1447    Ind1448        No  ...                       11                    11
# 1448    Ind1449        No  ...                        0                     4
# 1449    Ind1450        No  ...                        1                     2
# 1450    Ind1451        No  ...                        1                     7
# 1451    Ind1452        No  ...                        1                     9
# 1452    Ind1453       Yes  ...                        0                     1
# 1453    Ind1454        No  ...                        0                     0
# 1454    Ind1455        No  ...                        0                     1
# 1455    Ind1456        No  ...                        2                     2
# 1456    Ind1457        No  ...                        0                     2
# 1457    Ind1458        No  ...                        0                     2
# 1458    Ind1459        No  ...                        1                     1
# 1459    Ind1460        No  ...                        0                     3
# 1460    Ind1461        No  ...                        0                     4
# 1461    Ind1462       Yes  ...                        2                     0
# 1462    Ind1463        No  ...                        9                     6
# 1463    Ind1464        No  ...                        1                     7
# 1464    Ind1465        No  ...                        0                     0
# 1465    Ind1466        No  ...                        0                     3
# 1466    Ind1467        No  ...                        1                     7
# 1467    Ind1468        No  ...                        0                     3
# 1468    Ind1469        No  ...                        0                     8
# 1469    Ind1470        No  ...                        1                     2
#
# [1470 rows x 35 columns]>

# %%
HR_Ext_df.columns
# Out:
# Index(['Individual', 'Attrition', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HR_Ext_df.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR_Ext_df.iloc[:,2:9]
# Out:
#       Age  BusinessTravel  ...  Education  EducationField
# 0      41               1  ...          2               1
# 1      49               2  ...          1               1
# 2      37               1  ...          2               6
# 3      33               2  ...          4               1
# 4      27               1  ...          1               2
# 5      32               2  ...          2               1
# 6      59               1  ...          3               2
# 7      30               1  ...          1               1
# 8      38               2  ...          3               1
# 9      36               1  ...          3               2
# 10     35               1  ...          3               2
# 11     29               1  ...          2               1
# 12     31               1  ...          1               1
# 13     34               1  ...          2               2
# 14     28               1  ...          3               1
# 15     29               1  ...          4               1
# 16     32               1  ...          2               1
# 17     22               3  ...          2               2
# 18     53               1  ...          4               1
# 19     38               1  ...          3               1
# 20     24               3  ...          2               6
# 21     36               1  ...          4               1
# 22     34               1  ...          4               1
# 23     21               1  ...          2               1
# 24     34               1  ...          1               2
# 25     53               1  ...          3               6
# 26     32               2  ...          1               1
# 27     42               1  ...          4               3
# 28     44               1  ...          4               2
# 29     46               1  ...          4               3
# ...   ...             ...  ...        ...             ...
# 1440   36               2  ...          2               1
# 1441   56               3  ...          4               1
# 1442   29               1  ...          4               2
# 1443   42               1  ...          3               1
# 1444   56               1  ...          2               4
# 1445   41               1  ...          4               1
# 1446   34               1  ...          3               3
# 1447   36               3  ...          4               3
# 1448   41               1  ...          3               1
# 1449   32               1  ...          3               4
# 1450   35               1  ...          4               1
# 1451   38               1  ...          2               1
# 1452   50               2  ...          4               1
# 1453   36               1  ...          4               3
# 1454   45               1  ...          3               1
# 1455   40               1  ...          4               1
# 1456   35               2  ...          4               1
# 1457   40               1  ...          4               2
# 1458   35               1  ...          4               1
# 1459   29               1  ...          2               6
# 1460   29               1  ...          4               2
# 1461   50               1  ...          3               3
# 1462   39               1  ...          1               3
# 1463   31               3  ...          3               2
# 1464   26               1  ...          3               6
# 1465   36               2  ...          2               2
# 1466   39               1  ...          1               2
# 1467   27               1  ...          3               1
# 1468   49               2  ...          3               2
# 1469   34               1  ...          3               2
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
print(len(HR_Ext_df[HR_Ext_df['Gender']==1]))
# Out:
# 882

# %%
print(len(HR_Ext_df[HR_Ext_df['Gender']==2]))
# Out:
# 588

# %%
print(len(HR_Ext_df[HR_Ext_df['Gender']==1])+len(HR_Ext_df[HR_Ext_df['Gender']==2]))
# Out:
# 1470

# %%
Gender1=sum(HR_Ext_df['Gender']==1)
Gender1
# Out:
# 882

# %%
Gender2=sum(HR_Ext_df['Gender']==2)
Gender2
# Out:
# 588

# %%
Gender1 + Gender2
# Out:
# 1470

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
iqr=HR_Ext_df_new.iloc[6].subtract(HR_Ext_df_new.iloc[4])
print(iqr)
# Out:
# Age                            13.00
# BusinessTravel                  1.00
# DailyRate                     692.00
# Department                      1.00
# DistanceFromHome               12.00
# Education                       2.00
# EducationField                  2.00
# EmployeeCount                   0.00
# EmployeeNumber               1064.50
# EnvironmentSatisfaction         2.00
# Gender                          1.00
# HourlyRate                     35.75
# JobInvolvement                  1.00
# JobLevel                        2.00
# JobRole                         3.00
# JobSatisfaction                 2.00
# MaritalStatus                   1.00
# MonthlyIncome                5468.00
# MonthlyRate                 12414.50
# NumCompaniesWorked              3.00
# OverTime                        1.00
# PercentSalaryHike               6.00
# PerformanceRating               0.00
# RelationshipSatisfaction        2.00
# StandardHours                   0.00
# StockOptionLevel                1.00
# TotalWorkingYears               9.00
# TrainingTimesLastYear           1.00
# WorkLifeBalance                 1.00
# YearsAtCompany                  6.00
# YearsInCurrentRole              5.00
# YearsSinceLastPromotion         3.00
# YearsWithCurrManager            5.00
# dtype: float64

# %%
iqr=(HR_Ext_df_new.iloc[6]-HR_Ext_df_new.iloc[4])
print(iqr)
# Out:
# Age                            13.00
# BusinessTravel                  1.00
# DailyRate                     692.00
# Department                      1.00
# DistanceFromHome               12.00
# Education                       2.00
# EducationField                  2.00
# EmployeeCount                   0.00
# EmployeeNumber               1064.50
# EnvironmentSatisfaction         2.00
# Gender                          1.00
# HourlyRate                     35.75
# JobInvolvement                  1.00
# JobLevel                        2.00
# JobRole                         3.00
# JobSatisfaction                 2.00
# MaritalStatus                   1.00
# MonthlyIncome                5468.00
# MonthlyRate                 12414.50
# NumCompaniesWorked              3.00
# OverTime                        1.00
# PercentSalaryHike               6.00
# PerformanceRating               0.00
# RelationshipSatisfaction        2.00
# StandardHours                   0.00
# StockOptionLevel                1.00
# TotalWorkingYears               9.00
# TrainingTimesLastYear           1.00
# WorkLifeBalance                 1.00
# YearsAtCompany                  6.00
# YearsInCurrentRole              5.00
# YearsSinceLastPromotion         3.00
# YearsWithCurrManager            5.00
# dtype: float64

# %%
#To find the iqr
HR_Ext_df_new=HR_Ext_df.describe()
iqr=HR_Ext_df_new.iloc[6].subtract(HR_Ext_df_new.iloc[4])
HR_Ext_df_new = HR_Ext_df_new.append(iqr, ignore_index=True)
HR_Ext_df_new['Index'] = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', 'iqr']
HR_Ext_df_new.set_index('Index',inplace=True)
HR_Ext_df_new
# Out:
#                Age  ...  YearsWithCurrManager
# Index               ...
# count  1470.000000  ...           1470.000000
# mean     36.923810  ...              4.123129
# std       9.135373  ...              3.568136
# min      18.000000  ...              0.000000
# 25%      30.000000  ...              2.000000
# 50%      36.000000  ...              3.000000
# 75%      43.000000  ...              7.000000
# max      60.000000  ...             17.000000
# iqr      13.000000  ...              5.000000
#
# [9 rows x 33 columns]

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
HR_Ext_df['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
HR_Ext_df['DailyRate'].median()
# Out:
# 802.0

# %%
HR_Ext_df['DailyRate'].var()
# Out:
# 162819.59373723628

# %%
#To find the variance , range and median
HR_Ext_df_new=HR_Ext_df.describe()
iqr=HR_Ext_df_new.iloc[6].subtract(HR_Ext_df_new.iloc[4])
HR_Ext_df_new = HR_Ext_df_new.append(iqr, ignore_index=True)
new_var=HR_Ext_df.var()
HR_Ext_df_new = HR_Ext_df_new.append(new_var, ignore_index=True)
new_range=HR_Ext_df_new.iloc[7].subtract(HR_Ext_df_new.iloc[3])
HR_Ext_df_new = HR_Ext_df_new.append(new_range, ignore_index=True)
new_median=HR_Ext_df.median()
HR_Ext_df_new = HR_Ext_df_new.append(new_median, ignore_index=True)
HR_Ext_df_new['Index'] = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', 'iqr', 'var', 'range', 'median']
HR_Ext_df_new.set_index('Index',inplace=True)
HR_Ext_df_new
# Out:
#                 Age  ...  YearsWithCurrManager
# Index                ...
# count   1470.000000  ...           1470.000000
# mean      36.923810  ...              4.123129
# std        9.135373  ...              3.568136
# min       18.000000  ...              0.000000
# 25%       30.000000  ...              2.000000
# 50%       36.000000  ...              3.000000
# 75%       43.000000  ...              7.000000
# max       60.000000  ...             17.000000
# iqr       13.000000  ...              5.000000
# var       83.455049  ...             12.731595
# range     42.000000  ...             17.000000
# median    36.000000  ...              3.000000
#
# [12 rows x 33 columns]

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
print (HR_Ext_df['Attrition'].describe())
# Out:
# count     1470
# unique       2
# top         No
# freq      1233
# Name: Attrition, dtype: object

# %%
import matplotlib.pyplot as plt
HR_Ext_df['Attrition'].value_counts().plot.bar(color='g')
plt.ylabel('Number Of Employees')
plt.xlabel('Currently Not Employed')
plt.title('Attrition Count')
plt.show()

# %%
import matplotlib.pyplot as plt
HR_Ext_df['Attrition'].value_counts().sort_index().plot.barh()
plt.xlabel('Number Of Employees')
plt.ylabel('Currently Not Employed')
plt.title('Attrition Count')
plt.show()

# %%
import matplotlib.pyplot as plt
HR_Ext_df.groupby('Attrition').size().plot(kind='bar',color='y')
plt.ylabel('Number Of Employees')
plt.xlabel('Currently Not Employed')
plt.title('Attrition Count')
plt.show()

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
print (HR_Ext_df['TotalWorkingYears'].describe())
# Out:
# count    1470.000000
# mean       11.279592
# std         7.780782
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
import matplotlib.pyplot as plt
HR_Ext_df.groupby('TotalWorkingYears').size().plot(kind='line',color='red')
plt.ylabel('Number Of Employees')
plt.xlabel('Years Of Experience')
plt.title(' Total Years Of Experience For All Employees ')
plt.show()

# %%
#End
print("That's all Folks !")
# Out:
# That's all Folks !
